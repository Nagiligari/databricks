# %% [markdown]
# #### this notebooks to explore all the magic commands in databricks

# %%
# %sql
select * from gizmobox.bronze.v_addresses

# %%
# %py
df = spark.sql("""select * from gizmobox.bronze.v_addresses where address_type = 'shipping'""")
df.display()

# %%
# %fs ls '/Volumes/gizmobox/landing/operational_data/addresses/'

# %%
# %pip install faker

# %%
# %run /Workspace/Shared/etl-with-apache-spark/02.Extract_Customer_Data

# %%
display(dbutils.fs.ls('/Volumes/gizmobox/landing/operational_data/addresses/'))

# %%
dbutils.secrets.listScopes()

# %%
dbutils.secrets.get(scope= 'nagiligari-scope', key = 'nagiligari-sp-clientid')

# %%
dbutils.widgets.text("region","")
region = dbutils.widgets.get("region")
print(region)
