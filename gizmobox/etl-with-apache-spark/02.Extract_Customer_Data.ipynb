# %%
# %fs ls '/Volumes/gizmobox/landing/operational_data/customers/'

# %% [markdown]
# ## Query Single JSON file

# %%
# %sql
select * from json.`/Volumes/gizmobox/landing/operational_data/customers/customers_2024_10.json`

# %% [markdown]
# ## Query Multiple JSON files

# %%
# %sql
select * from json.`/Volumes/gizmobox/landing/operational_data/customers/`

# %% [markdown]
# ## adding metadata of file using input_file_name() and _metadata.file_path

# %%
# %sql
select input_file_name() as file_path, -- Deprecated from Databricks Runtime 13.3 and above
       *,_metadata.file_path as metafile_path
from json.`/Volumes/gizmobox/landing/operational_data/customers/`

# %% [markdown]
# ## CREATING VIEW

# %%
# %sql
CREATE OR REPLACE VIEW gizmobox.bronze.v_customers AS
select  *,_metadata.file_path as file_path from json.`/Volumes/gizmobox/landing/operational_data/customers/`;

# %%
# %sql
select * from gizmobox.bronze.v_customers

# %% [markdown]
# ## Create Temp View

# %%
# %sql
CREATE OR REPLACE TEMP VIEW tv_customers AS
select  *,_metadata.file_path as file_path from json.`/Volumes/gizmobox/landing/operational_data/customers/`;

# %%
# %sql
select * from tv_customers

# %% [markdown]
# ## Create Global Temp View

# %%
# %sql
CREATE OR REPLACE GLOBAL TEMP VIEW gtv_customers AS
select  *,_metadata.file_path as file_path from json.`/Volumes/gizmobox/landing/operational_data/customers/`;

# %%
# %sql
select * from global_temp.gtv_customers
