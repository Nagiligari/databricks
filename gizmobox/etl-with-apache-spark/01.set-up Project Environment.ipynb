# %%
# %fs ls 'abfss://gizmobox@nagiligaristg.dfs.core.windows.net'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>abfss://gizmobox@nagiligaristg.dfs.core.windows.net/landing/</td><td>landing/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS nagiligaristg_ext_nagiligariuc
    URL 'abfss://gizmobox@nagiligaristg.dfs.core.windows.net'
    WITH (STORAGE CREDENTIAL nagiligaristgcredential)
    COMMENT 'External loaction for gizmobox'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SHOW CATALOGS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>catalog</th></tr></thead><tbody><tr><td>samples</td></tr><tr><td>system</td></tr></tbody></table></div>

# %%
# %sql
CREATE CATALOG IF NOT EXISTS gizmobox
   MANAGED LOCATION 'abfss://gizmobox@nagiligaristg.dfs.core.windows.net/'
   COMMENT 'This is the catalog for GizmoBox Data Lakehouse';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SELECT current_catalog();
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_catalog()</th></tr></thead><tbody><tr><td>nagiligari_dbws</td></tr></tbody></table></div>

# %%
# %sql
USE CATALOG gizmobox;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS gizmobox.landing
    MANAGED LOCATION 'abfss://gizmobox@nagiligaristg.dfs.core.windows.net/landing'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SHOW SCHEMAS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>databaseName</th></tr></thead><tbody><tr><td>default</td></tr><tr><td>information_schema</td></tr><tr><td>landing</td></tr></tbody></table></div>

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS gizmobox.bronze
    MANAGED LOCATION 'abfss://gizmobox@nagiligaristg.dfs.core.windows.net/bronze';
CREATE SCHEMA IF NOT EXISTS gizmobox.silver
    MANAGED LOCATION 'abfss://gizmobox@nagiligaristg.dfs.core.windows.net/silver';
CREATE SCHEMA IF NOT EXISTS gizmobox.gold
    MANAGED LOCATION 'abfss://gizmobox@nagiligaristg.dfs.core.windows.net/gold';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
USE CATALOG gizmobox;
USE SCHEMA landing;
CREATE EXTERNAL VOLUME gizmobox.landing.operational_data
LOCATION 'abfss://gizmobox@nagiligaristg.dfs.core.windows.net/landing/operational_data/';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %fs ls '/Volumes/gizmobox/landing/operational_data'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/gizmobox/landing/operational_data/addresses/</td><td>addresses/</td><td>0</td><td>1785333693000</td></tr><tr><td>dbfs:/Volumes/gizmobox/landing/operational_data/customers/</td><td>customers/</td><td>0</td><td>1785333693000</td></tr><tr><td>dbfs:/Volumes/gizmobox/landing/operational_data/memberships/</td><td>memberships/</td><td>0</td><td>1785333693000</td></tr><tr><td>dbfs:/Volumes/gizmobox/landing/operational_data/orders/</td><td>orders/</td><td>0</td><td>1785333693000</td></tr></tbody></table></div>

# %%
# %sql
DROP CATALOG IF EXISTS gizmobox CASCADE
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
