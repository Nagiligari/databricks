-- %% [markdown]
-- ### Check whether the workspace is attached to a Unity Catalog Metastore

-- %%
SELECT current_metastore();
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_metastore()</th></tr></thead><tbody><tr><td>azure:uksouth:4a4f4dbc-c8b0-49e4-ae53-f2d464d2ea0e</td></tr></tbody></table></div>
