-- %% [markdown]
-- # Data-Level Security Using Row Filters and Column Masks
--
-- This notebook demonstrates how data-level security can be implemented directly on a table using row filters and column masks.
--
-- Unlike dynamic views, where logic is defined within a view, this approach applies security rules directly to the table. These rules are enforced automatically whenever the table is queried.
--
-- The implementation covers two key capabilities:
--
-- - Row-Level Security: Controls which rows are visible to a user
-- - Column-Level Masking: Controls how sensitive values are displayed
--
-- A simple sales dataset is used to illustrate how different users receive different results when querying the same table
--
-- > **Note:** Row filters and column masks are not supported on Dedicated (Single User) clusters as of now.
-- > Use a Shared cluster or a Serverless cluster to run this demo.

-- %% [markdown]
-- #### Step 1: Set up the schema for the table

-- %%
USE CATALOG demo;
USE SCHEMA data_security;

-- %% [markdown]
-- #### Step 2: Create the table
-- A table is defined to represent sales data across multiple regions.

-- %%
CREATE OR REPLACE TABLE sales_secured (
  id INT,
  region STRING,
  email STRING,
  revenue INT
);

-- %% [markdown]
-- #### Step 3: Insert Sample Data

-- %%
INSERT INTO sales_secured VALUES
  (1, 'UK', 'john.doe@email.com', 10000),
  (2, 'US', 'mike.smith@email.com', 20000),
  (3, 'UK', 'sara.jones@email.com', 15000),
  (4, 'US', 'david.brown@email.com', 25000),
  (5, 'UK', 'emma.wilson@email.com', 18000);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

-- %%
SELECT * FROM sales_secured;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>region</th><th>email</th><th>revenue</th></tr></thead><tbody><tr><td>1</td><td>UK</td><td>john.doe@email.com</td><td>10000</td></tr><tr><td>2</td><td>US</td><td>mike.smith@email.com</td><td>20000</td></tr><tr><td>3</td><td>UK</td><td>sara.jones@email.com</td><td>15000</td></tr><tr><td>4</td><td>US</td><td>david.brown@email.com</td><td>25000</td></tr><tr><td>5</td><td>UK</td><td>emma.wilson@email.com</td><td>18000</td></tr></tbody></table></div>

-- %% [markdown]
-- #### Step 4: Define Row Filter Function
-- The function evaluates the user’s group membership and returns a condition that determines whether a row should be included in the result.
--
-- For example:
--
-- - Users in the UK group are allowed to view UK records
-- - Users in the US group are allowed to view US records
-- - Admin users are allowed to view all records

-- %%
CREATE OR REPLACE FUNCTION fn_filter_region (region STRING)
RETURN 
  is_account_group_member('admin-sg')
  OR (is_account_group_member('uk-sg') AND region = 'UK')
  OR (is_account_group_member('us-sg') AND region = 'US');

-- %% [markdown]
-- #### Step 5: Apply Row Filter to Table
-- The row filter function is attached to the table. Once applied, the function is evaluated automatically at query time, and only the rows that satisfy the condition are returned.

-- %%
ALTER TABLE sales_secured
SET ROW FILTER fn_filter_region ON (region);

-- %%
DESC EXTENDED sales_secured;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>id</td><td>int</td><td>null</td></tr><tr><td>region</td><td>string</td><td>null</td></tr><tr><td>email</td><td>string</td><td>null</td></tr><tr><td>revenue</td><td>int</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Statistics Columns</td><td></td><td></td></tr><tr><td>Column Names</td><td>id, region, email, revenue</td><td></td></tr><tr><td>Column Selection Method</td><td>first-32</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>demo</td><td></td></tr><tr><td>Database</td><td>data_security</td><td></td></tr><tr><td>Table</td><td>sales_secured</td><td></td></tr><tr><td>Created Time</td><td>Thu May 07 19:55:19 UTC 2026</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark </td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Location</td><td>abfss://unity-catalog-storage@dbstorageacrbro5snaai4.dfs.core.windows.net/3312650539267414/__unitystorage/catalogs/0a0fc67f-10e5-42cd-a069-c4633a669ec6/tables/899df8f8-fc18-4062-98d2-5698a1f587ea</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>cloudboxacademy@gmail.com</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Predictive Optimization</td><td>ENABLE (inherited from METASTORE metastore_azure_uksouth)</td><td></td></tr><tr><td>Table Properties</td><td>[delta.enableDeletionVectors=true,delta.enableRowTracking=true,delta.feature.appendOnly=supported,delta.feature.deletionVectors=supported,delta.feature.domainMetadata=supported,delta.feature.invariants=supported,delta.feature.rowTracking=supported,delta.minReaderVersion=3,delta.minWriterVersion=7,delta.parquet.compression.codec=zstd,delta.rowTracking.materializedRowCommitVersionColumnName=_row-commit-version-col-ec7e7075-f569-4e7a-ab4a-f9e5d05907e5,delta.rowTracking.materializedRowIdColumnName=_row-id-col-2eb5e787-6b80-4060-9161-d8bda474c3ae]</td><td></td></tr><tr><td>Row Filter</td><td>`demo`.`data_security`.`fn_filter_region` ON (region)</td><td></td></tr></tbody></table></div>

-- %%
SELECT * FROM sales_secured;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>region</th><th>email</th><th>revenue</th></tr></thead><tbody><tr><td>1</td><td>UK</td><td>john.doe@email.com</td><td>10000</td></tr><tr><td>3</td><td>UK</td><td>sara.jones@email.com</td><td>15000</td></tr><tr><td>5</td><td>UK</td><td>emma.wilson@email.com</td><td>18000</td></tr></tbody></table></div>

-- %% [markdown]
-- #### Step 6: Define Column Mask Function
-- The function evaluates the user’s group membership and determines whether to return the original value or a masked version.
--
-- For example:
-- - Admin users can view the full email address
-- - Other users see a masked version of the email

-- %%
CREATE OR REPLACE FUNCTION fn_mask_email (email STRING)
RETURN 
    CASE 
         WHEN is_account_group_member('admin-sg') THEN email
         ELSE concat(substr(email, 1, 1), '***@', split(email, '@')[1])
    END;

-- %% [markdown]
-- #### Step 7: Apply Column Mask
-- The masking function is attached to the email column. Once applied, the function is executed automatically whenever the column is queried.

-- %%
ALTER TABLE sales_secured
ALTER COLUMN email SET MASK fn_mask_email;

-- %%
DESC EXTENDED sales_secured;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>id</td><td>int</td><td>null</td></tr><tr><td>region</td><td>string</td><td>null</td></tr><tr><td>email</td><td>string</td><td>null</td></tr><tr><td>revenue</td><td>int</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Statistics Columns</td><td></td><td></td></tr><tr><td>Column Names</td><td>id, region, email, revenue</td><td></td></tr><tr><td>Column Selection Method</td><td>first-32</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>demo</td><td></td></tr><tr><td>Database</td><td>data_security</td><td></td></tr><tr><td>Table</td><td>sales_secured</td><td></td></tr><tr><td>Created Time</td><td>Thu May 07 19:55:19 UTC 2026</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark </td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Location</td><td>abfss://unity-catalog-storage@dbstorageacrbro5snaai4.dfs.core.windows.net/3312650539267414/__unitystorage/catalogs/0a0fc67f-10e5-42cd-a069-c4633a669ec6/tables/899df8f8-fc18-4062-98d2-5698a1f587ea</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>cloudboxacademy@gmail.com</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Predictive Optimization</td><td>ENABLE (inherited from METASTORE metastore_azure_uksouth)</td><td></td></tr><tr><td>Table Properties</td><td>[delta.enableDeletionVectors=true,delta.enableRowTracking=true,delta.feature.appendOnly=supported,delta.feature.deletionVectors=supported,delta.feature.domainMetadata=supported,delta.feature.invariants=supported,delta.feature.rowTracking=supported,delta.minReaderVersion=3,delta.minWriterVersion=7,delta.parquet.compression.codec=zstd,delta.rowTracking.materializedRowCommitVersionColumnName=_row-commit-version-col-ec7e7075-f569-4e7a-ab4a-f9e5d05907e5,delta.rowTracking.materializedRowIdColumnName=_row-id-col-2eb5e787-6b80-4060-9161-d8bda474c3ae]</td><td></td></tr><tr><td>Row Filter</td><td>`demo`.`data_security`.`fn_filter_region` ON (region)</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Column Masks</td><td></td><td></td></tr><tr><td>email</td><td>`demo`.`data_security`.`fn_mask_email`</td><td></td></tr></tbody></table></div>

-- %%
SELECT * FROM sales_secured;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>region</th><th>email</th><th>revenue</th></tr></thead><tbody><tr><td>1</td><td>UK</td><td>j***@email.com</td><td>10000</td></tr><tr><td>3</td><td>UK</td><td>s***@email.com</td><td>15000</td></tr><tr><td>5</td><td>UK</td><td>e***@email.com</td><td>18000</td></tr></tbody></table></div>
