# %% [markdown]
# # Introduction to Notebooks
# ## Heading 2
# - bullet 1
# - bullet 2
#
# This notebook gives you an introduction to databricks notebooks!

# %%
print('hello')
print('bye')
# Out:
# hello
# bye

# %%
print('Hello Again')
# Out:
# Hello Again

# %%
# %sql
SELECT 'Hello from SQL'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Hello from SQL</th></tr></thead><tbody><tr><td>Hello from SQL</td></tr></tbody></table></div>
