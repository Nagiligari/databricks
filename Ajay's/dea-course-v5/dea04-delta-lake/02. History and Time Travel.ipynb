-- %% [markdown]
-- ## History and Time Travel
-- 1. Query Delta Lake table history
-- 1. Query previous versions of the data
-- 1. Query data from a specific time.
-- 1. Restore data to a specific version.

-- %% [markdown]
-- #### 1. Query Delta Lake Table History

-- %%
DESCRIBE HISTORY demo.delta_lake.companies;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>2</td><td>2025-01-07T11:47:04Z</td><td>3341927249304550</td><td>cloudboxacademy@gmail.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(3425405062441743)</td><td>1108-132705-qy6b0rb7</td><td>1</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 3, numOutputBytes -> 1068)</td><td>null</td><td>Databricks-Runtime/15.4.x-scala2.12</td></tr><tr><td>1</td><td>2025-01-07T11:45:12Z</td><td>3341927249304550</td><td>cloudboxacademy@gmail.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(3425405062441743)</td><td>1108-132705-qy6b0rb7</td><td>0</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 1002)</td><td>null</td><td>Databricks-Runtime/15.4.x-scala2.12</td></tr><tr><td>0</td><td>2025-01-07T11:41:19Z</td><td>3341927249304550</td><td>cloudboxacademy@gmail.com</td><td>CREATE TABLE</td><td>Map(partitionBy -> [], clusterBy -> [], description -> null, isManaged -> true, properties -> {"delta.enableDeletionVectors":"true"}, statsOnLoad -> false)</td><td>null</td><td>List(3425405062441743)</td><td>1108-132705-qy6b0rb7</td><td>null</td><td>WriteSerializable</td><td>true</td><td>Map()</td><td>null</td><td>Databricks-Runtime/15.4.x-scala2.12</td></tr></tbody></table></div>

-- %% [markdown]
-- #### 2. Query Data from a Specific Version

-- %%
SELECT * FROM demo.delta_lake.companies;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>company_name</th><th>founded_date</th><th>country</th></tr></thead><tbody><tr><td>Microsoft</td><td>1975-04-04</td><td>USA</td></tr><tr><td>Google</td><td>1998-09-04</td><td>USA</td></tr><tr><td>Amazon</td><td>1994-07-05</td><td>USA</td></tr><tr><td>Apple</td><td>1976-04-01</td><td>USA</td></tr></tbody></table></div>

-- %%
SELECT * FROM demo.delta_lake.companies
VERSION AS OF 1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>company_name</th><th>founded_date</th><th>country</th></tr></thead><tbody><tr><td>Apple</td><td>1976-04-01</td><td>USA</td></tr></tbody></table></div>

-- %% [markdown]
-- #### 3. Query Data from a Specific Time

-- %%
SELECT * FROM demo.delta_lake.companies
TIMESTAMP AS OF '2025-01-07T11:45:12.000+00:00';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>company_name</th><th>founded_date</th><th>country</th></tr></thead><tbody><tr><td>Apple</td><td>1976-04-01</td><td>USA</td></tr></tbody></table></div>

-- %% [markdown]
-- #### 4. Restore Data in the Table to a Specific Version

-- %%
RESTORE TABLE demo.delta_lake.companies VERSION AS OF 1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>table_size_after_restore</th><th>num_of_files_after_restore</th><th>num_removed_files</th><th>num_restored_files</th><th>removed_files_size</th><th>restored_files_size</th></tr></thead><tbody><tr><td>1002</td><td>1</td><td>1</td><td>0</td><td>1068</td><td>0</td></tr></tbody></table></div>

-- %%
SELECT * FROM demo.delta_lake.companies;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>company_name</th><th>founded_date</th><th>country</th></tr></thead><tbody><tr><td>Apple</td><td>1976-04-01</td><td>USA</td></tr></tbody></table></div>

-- %%
DESC HISTORY demo.delta_lake.companies;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>3</td><td>2025-01-07T12:29:01Z</td><td>3341927249304550</td><td>cloudboxacademy@gmail.com</td><td>RESTORE</td><td>Map(version -> 1, timestamp -> null)</td><td>null</td><td>List(1174627871086104)</td><td>1108-132705-qy6b0rb7</td><td>2</td><td>Serializable</td><td>false</td><td>Map(numRestoredFiles -> 0, removedFilesSize -> 1068, numRemovedFiles -> 1, restoredFilesSize -> 0, numOfFilesAfterRestore -> 1, tableSizeAfterRestore -> 1002)</td><td>null</td><td>Databricks-Runtime/15.4.x-scala2.12</td></tr><tr><td>2</td><td>2025-01-07T11:47:04Z</td><td>3341927249304550</td><td>cloudboxacademy@gmail.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(3425405062441743)</td><td>1108-132705-qy6b0rb7</td><td>1</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 3, numOutputBytes -> 1068)</td><td>null</td><td>Databricks-Runtime/15.4.x-scala2.12</td></tr><tr><td>1</td><td>2025-01-07T11:45:12Z</td><td>3341927249304550</td><td>cloudboxacademy@gmail.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(3425405062441743)</td><td>1108-132705-qy6b0rb7</td><td>0</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 1002)</td><td>null</td><td>Databricks-Runtime/15.4.x-scala2.12</td></tr><tr><td>0</td><td>2025-01-07T11:41:19Z</td><td>3341927249304550</td><td>cloudboxacademy@gmail.com</td><td>CREATE TABLE</td><td>Map(partitionBy -> [], clusterBy -> [], description -> null, isManaged -> true, properties -> {"delta.enableDeletionVectors":"true"}, statsOnLoad -> false)</td><td>null</td><td>List(3425405062441743)</td><td>1108-132705-qy6b0rb7</td><td>null</td><td>WriteSerializable</td><td>true</td><td>Map()</td><td>null</td><td>Databricks-Runtime/15.4.x-scala2.12</td></tr></tbody></table></div>
