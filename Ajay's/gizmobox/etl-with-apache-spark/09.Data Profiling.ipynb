# %%
# %sql
select * from gizmobox.bronze.v_customers
# Out:
# Databricks data profile. Run in Databricks to view.

# %%
df = spark.table("gizmobox.bronze.v_customers")
dbutils.data.summarize(df)

# %%
# %sql
SELECT COUNT(*) as total_count, COUNT(customer_id) as actual_customer_id,count(email),count(telephone)
FROM gizmobox.bronze.v_customers

# %%
# %sql
SELECT COUNT(*) as total_count, COUNT_IF(customer_id is null) as actual_customer_id, COUNT_IF(email is null), COUNT_IF(telephone is null)
FROM gizmobox.bronze.v_customers

# %%
# %sql
select count(*) as cnt,count(distinct customer_id) as unique_cnt from gizmobox.bronze.v_customers where customer_id is not null
