# %% [markdown]
# - the files addresses are tab delimiter files and having headers, for this kind of files databricks recommands to use Table Valued Functions(eg. read_files) or create external tables on files

# %%
# %fs ls "/Volumes/gizmobox/landing/operational_data/addresses/"

# %%
# %sql
select * from csv.`/Volumes/gizmobox/landing/operational_data/addresses/addresses_2024_10.tsv`

# %%
# %sql
select * 
from read_files('/Volumes/gizmobox/landing/operational_data/addresses/', 
                    format => 'csv',delimiter => '\t',header =>true)

# %%
# %sql
CREATE OR REPLACE VIEW gizmobox.bronze.v_addresses
AS
select * 
from read_files('/Volumes/gizmobox/landing/operational_data/addresses/', 
                    format => 'csv',delimiter => '\t',header =>true)

# %%
# %sql
select * from gizmobox.bronze.v_addresses
