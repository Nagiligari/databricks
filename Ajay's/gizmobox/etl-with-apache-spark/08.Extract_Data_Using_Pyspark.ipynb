# %%
df_customers = spark.sql("select * from json.`/Volumes/gizmobox/landing/operational_data/customers/`")
display(df_customers)

# %%
spark.sql("""
          CREATE OR REPLACE TEMP VIEW tv_customers
          AS
          SELECT * FROM json.`/Volumes/gizmobox/landing/operational_data/customers/`"""
          )

# %%
# %sql
select * from tv_customers

# %%
df = (
    spark
    .read
    .format("JSON")
    .load("/Volumes/gizmobox/landing/operational_data/customers/")
)
display(df)

# %%
df_address = spark.table('gizmobox.bronze.v_addresses')
display(df_address)
