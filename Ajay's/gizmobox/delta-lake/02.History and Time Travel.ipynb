# %%
# %sql
DESCRIBE HISTORY gizmobox.demo.compaines

# %%
# %sql
SELECt * FROM gizmobox.demo.compaines VERSION AS OF 1

# %%
# %sql
SELECt * FROM gizmobox.demo.compaines TIMESTAMP AS OF '2026-09-18T05:33:35.000+00:00'

# %%
# %sql
RESTORE TABLE gizmobox.demo.compaines VERSION AS OF 1

# %%
# %sql
select * from gizmobox.demo.compaines
